# %% [markdown]
# <a href="https://colab.research.google.com/github/comii98/FaceRecognition/blob/main/MilicaSantra%C4%8DIT52_2017FaceRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FACE RECOGNITION APPLICATION**

# %% [markdown]
# #**Uvod**
#
# U narednim primerima ćemo videti primenu tehnika mašinskog učenja kao i dubokog učenja za rešavanje određenih problema obrade fotografija, u ovom primeru ćemo se pozabaviti prepoznavanjem lica.
#
# * Prvi deo rada je detaljnije upoznavanje sa odabranim tehinkama.
#   Započećemo sa problemom prepoznavanja lica, odnosno detekcija lica za koje je mreža trenirana, zatim ću koristiti model dubokog učenja za rešavanje određenih problema, kako bi mreža bila sposobna da na slici sa više lica detektuje samo ona za koje je trenirana. Takođe ću pokazati prepoznavanje lica na slici koja je upravo uslikana mojom web kamerom.
#
#
# * Drugi deo rada je obada fotografija iz dataseta.
#   Nakon par primera koje smo gore prošli malo ćemo se i pozabaviti prepoznavanjem lica iz dataseta koji sam dobila kao zadatak.
#
#
# Na samom kraju ću dati neki svoj zaključak kao i iskustvo rada na ovom projektu.

# %% [markdown]
# # **Face Recognition**
#
#   Tehnologija prepoznavanja lica je metod identifikovanja ili verifikovanja identiteta osobe posredstvom njihovog lica.Ova tehnologija može biti korišćena tako da prepoznaje identitet osoba na fotografijama, video snimcima ili u realnom vremenu.
#
#   Prva generacija softvera je bila poluautomatska, što znači da se prvo određivao položaj pojedinih karakterističnih crta lica na fotografiji – kao što su oči, nos, usta, uši – a potom su se vršila matematička merenja radi poređenja. U njihov rad je morao biti uključen i sam korisnik softvera.
#
#   Prednost korišćenja ove tehnologije se ogleda i u tome što može da utiče na odvraćanje od protivzakonitog i antisocijalnog ponašanja, dok je mana ove tehnologije ugrožavanje privatnosti.
#
#   Sistem za prepoznavanje lica je tehnologija sposobna da upari ljudsko lice sa digitalne slike ili video okvira sa bazom podataka lica, koja se obično koristi za autentifikaciju korisnika putem usluga verifikacije ličnih podataka, radi precizno određivanjem i merenjem crta lica sa date slike.
#
#   Prepoznavanje i manipulisanje licima u Python-u ili iz komandne linije pomoću najjednostavnijih biblioteka za prepoznavanje lica na svetu.
# Napravljeno pomoću dlib-ovog najsavremenijeg prepoznavanja lica,
# izgrađena dubokim učenjem. Model ima tačnost od 99,38%.
# Ovo takođe pruža jednostavan alat za naredbenu liniju face_recognition koji vam omogućava prepoznavanje lica u folderu slika iz komandne linije!

# %% [markdown]
# # **OpenCV**
#
#
# OpenCV je najpopularnija biblioteka za kompijuter vision. Prvobitno napisan na C / C ++, sada pruža veze za Python.
#
# OpenCV koristi algoritme mašinskog učenja za traženje lica unutar slike. Budući da su lica toliko komplikovana, ne postoji jedan jednostavan test koji će vam reći da li je lice pronađeno ili ne. Umesto toga, postoje hiljade malih obrazaca i karakteristika koje moraju da se podudaraju. Algoritmi razdvajaju zadatak prepoznavanja lica na hiljade manjih zadataka veličine zalogaja, od kojih je svaki lako rešiv. Ovi zadaci se nazivaju i klasifikatorima.
#
# OpenCV kaskada razlaže problem otkrivanja lica u više faza. Za svaki blok radi vrlo grub i brz test. Ako to prođe, uradiće malo detaljniji test itd. Algoritam može imati 30 do 50 ovih faza ili kaskada, a lice će otkriti samo ako sve faze prođu.
#
# Prednost je u tome što će većina slika negativnih vrednosti dati u prvih nekoliko faza, što znači da algoritam neće gubiti vreme testirajući svih 6.000 karakteristika na njemu. Umesto satima, otkrivanje lica sada se može obaviti u realnom vremenu.

# %% [markdown]
# # **OS**
#
# OS modul u Python-u koji pruža funkcije za interakciju sa operativnim sistemom. OS dolazi pod Python-ovim standardnim uslužnim modulima. Ovaj modul pruža prenosni način korišćenja funkcionalnosti zavisne od operativnog sistema. Moduli * os * i * os.path * uključuju mnoge funkcije za interakciju sa sistemom datoteka

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 35kB/s
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566184 sha256=b12472ba27b19f93f69d1803f81951e73cf080ea968a270a4f885e969c6e717a
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
# !mkdir known
# !wget https://www.biography.com/.image/t_share/MTY2MzU3Nzk2OTM2MjMwNTkx/elon_musk_royal_society.jpg -O known/elon.jpg
# !wget https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_400x400.jpg -O known/bill.jpg
# !wget https://www.biography.com/.image/t_share/MTE4MDAzNDEwNzg5ODI4MTEw/barack-obama-12782369-1-402.jpg -O known/obama.jpg
# Out:
# --2021-07-06 13:11:50--  https://www.biography.com/.image/t_share/MTY2MzU3Nzk2OTM2MjMwNTkx/elon_musk_royal_society.jpg
# Resolving www.biography.com (www.biography.com)... 151.101.66.98, 151.101.194.98, 151.101.2.98, ...
# Connecting to www.biography.com (www.biography.com)|151.101.66.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151791 (148K) [image/jpeg]
# Saving to: ‘known/elon.jpg’
#
# known/elon.jpg      100%[===================>] 148.23K  --.-KB/s    in 0.02s
#
# 2021-07-06 13:11:50 (9.03 MB/s) - ‘known/elon.jpg’ saved [151791/151791]
#
# --2021-07-06 13:11:50--  https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_400x400.jpg
# Resolving pbs.twimg.com (pbs.twimg.com)... 72.21.91.70, 2606:2800:220:13d:2176:94a:948:148e
# Connecting to pbs.twimg.com (pbs.twimg.com)|72.21.91.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23065 (23K) [image/jpeg]
# Saving to: ‘known/bill.jpg’
#
# known/bill.jpg      100%[===================>]  22.52K  --.-KB/s    in 0s
#
# 2021-07-06 13:11:50 (248 MB/s) - ‘known/bill.jpg’ saved [23065/23065]
#
# --2021-07-06 13:11:50--  https://www.biography.com/.image/t_share/MTE4MDAzNDEwNzg5ODI4MTEw/barack-obama-12782369-1-402.jpg
# Resolving www.biography.com (www.biography.com)... 151.101.130.98, 151.101.194.98, 151.101.2.98, ...
# Connecting to www.biography.com (www.biography.com)|151.101.130.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194499 (190K) [image/jpeg]
# Saving to: ‘known/obama.jpg’
#
# known/obama.jpg     100%[===================>] 189.94K  --.-KB/s    in 0.02s
#
# 2021-07-06 13:11:50 (12.2 MB/s) - ‘known/obama.jpg’ saved [194499/194499]

# %%
# !mkdir unknown
# !wget https://i.insider.com/5ddfa893fd9db26b8a4a2df7 -O unknown/1.jpg
# !wget https://cdn-images-1.medium.com/max/1200/1*aEoYLgy4z1lT1kW7dqWzBg.jpeg -O unknown/2.jpg
# !wget https://media2.s-nbcnews.com/j/newscms/2017_46/2224911/171113-bill-gates-se-247p_043bd413c63b2a97abf11bfad747538d.fit-760w.jpg -O unknown/3.jpg
# !wget https://specials-images.forbesimg.com/imageserve/1184274010/960x0.jpg -O unknown/4.jpg
# Out:
# --2021-07-06 13:12:32--  https://i.insider.com/5ddfa893fd9db26b8a4a2df7
# Resolving i.insider.com (i.insider.com)... 151.101.2.217, 151.101.66.217, 151.101.130.217, ...
# Connecting to i.insider.com (i.insider.com)|151.101.2.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2324104 (2.2M) [image/png]
# Saving to: ‘unknown/1.jpg’
#
# unknown/1.jpg       100%[===================>]   2.22M  --.-KB/s    in 0.05s
#
# 2021-07-06 13:12:32 (42.4 MB/s) - ‘unknown/1.jpg’ saved [2324104/2324104]
#
# Warning: wildcards not supported in HTTP.
# --2021-07-06 13:12:32--  https://cdn-images-1.medium.com/max/1200/1*aEoYLgy4z1lT1kW7dqWzBg.jpeg
# Resolving cdn-images-1.medium.com (cdn-images-1.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9804, ...
# Connecting to cdn-images-1.medium.com (cdn-images-1.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119795 (117K) [image/jpeg]
# Saving to: ‘unknown/2.jpg’
#
# unknown/2.jpg       100%[===================>] 116.99K  --.-KB/s    in 0.02s
#
# 2021-07-06 13:12:32 (6.59 MB/s) - ‘unknown/2.jpg’ saved [119795/119795]
#
# --2021-07-06 13:12:32--  https://media2.s-nbcnews.com/j/newscms/2017_46/2224911/171113-bill-gates-se-247p_043bd413c63b2a97abf11bfad747538d.fit-760w.jpg
# Resolving media2.s-nbcnews.com (media2.s-nbcnews.com)... 104.65.188.131, 2600:1406:1400:6a6::a1d, 2600:1406:1400:688::a1d
# Connecting to media2.s-nbcnews.com (media2.s-nbcnews.com)|104.65.188.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49760 (49K) [image/jpeg]
# Saving to: ‘unknown/3.jpg’
#
# unknown/3.jpg       100%[===================>]  48.59K  --.-KB/s    in 0.05s
#
# 2021-07-06 13:12:32 (1014 KB/s) - ‘unknown/3.jpg’ saved [49760/49760]
#
# --2021-07-06 13:12:32--  https://specials-images.forbesimg.com/imageserve/1184274010/960x0.jpg
# Resolving specials-images.forbesimg.com (specials-images.forbesimg.com)... 151.101.2.49, 151.101.66.49, 151.101.130.49, ...
# Connecting to specials-images.forbesimg.com (specials-images.forbesimg.com)|151.101.2.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38695 (38K) [image/jpeg]
# Saving to: ‘unknown/4.jpg’
#
# unknown/4.jpg       100%[===================>]  37.79K  --.-KB/s    in 0.001s
#
# 2021-07-06 13:12:33 (29.6 MB/s) - ‘unknown/4.jpg’ saved [38695/38695]

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

# Ovo je primer učenja mreže koja će detektovati lica koja je naučila 
# kao i neprepoznavati lica koja ne zna

def read_img(path):
    img = cv2.imread(path)
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

# Pravljenje niza sa slika kao i učenje mreže

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    img = read_img(known_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]
    known_encodings.append(img_enc)
    known_names.append(file.split('.')[0])

# Lice koje mreza nije naučena neće izlistavati

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    print("Processing", file)
    img = read_img(unknown_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]

    results = face_recognition.compare_faces(known_encodings, img_enc)
    # print(face_recognition.face_distance(known_encodings, img_enc))

    # Iscrtavanje svih slika jedno ispod drugih

    for i in range(len(results)):
        if results[i]:
            name = known_names[i]
            (top, right, bottom, left) = face_recognition.face_locations(img)[0]
            cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2.putText(img, name, (left+2, bottom+20), cv2.FONT_HERSHEY_PLAIN, 1, (255, 255, 255), 1)
            cv2_imshow(img)
            

    # Prikazivanje rezultujućih fotografija
# Out:
# Processing 4.jpg
# <PIL.Image.Image image mode=RGB size=500x333 at 0x7F9EF005B410>
# Processing 2.jpg
# Processing 3.jpg
# <PIL.Image.Image image mode=RGB size=500x303 at 0x7F9EF005B710>
# Processing 1.jpg
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F9EF003AA50>

# %% [markdown]
# # **Primer prepoznavanja više lica na slici**

# %% [markdown]
# **NumPy**
#
# NumPy je biblioteka za programski jezik Python, koja dodaje podršku za velike, višedimenzionalne nizove i matrice, zajedno sa velikom kolekcijom matematičkih funkcija na visokom nivou za rad na tim nizovima. Rodonačelnika NumPy-a, Numeric-a, prvobitno je kreirao Jim Hugunin uz doprinos nekoliko drugih programera. 2005. Travis Oliphant je stvorio NumPy ugrađivanjem karakteristika konkurentskog Numarrai-a u Numeric, sa opsežnim modifikacijama. NumPy je softver otvorenog koda i ima mnogo saradnika

# %% [markdown]
# **Pillow**
#
# PIL je Python Imaging biblioteka Fredrika Lunda i saradnika.
# Pithon Imaging biblioteka je besplatna i otvorena biblioteka dodatne biblioteke za programski jezik Python koja dodaje podršku za otvaranje, manipulisanje i čuvanje mnogih različitih formata datoteka slika. Dostupan je za Windows, Mac OS Ks i Linux. Najnovija verzija PIL-a je 1.1.7, objavljena je u septembru 2009. godine i podržava Python 1.5.2–2.7.
#
#
# Ova biblioteka pruža opsežnu podršku za format datoteke, efikasnu internu reprezentaciju i prilično moćne mogućnosti obrade slika.
#
# Osnovna biblioteka slika dizajnirana je za brzi pristup podacima uskladištenim u nekoliko osnovnih formata piksela. Trebalo bi da pruži solidnu osnovu za opšti alat za obradu slika.

# %%
# !wget https://www.incimages.com/uploaded_files/image/1920x1080/getty_869035584_390187.jpg -O known/biden.jpg
# Out:
# --2021-07-06 13:24:14--  https://www.incimages.com/uploaded_files/image/1920x1080/getty_869035584_390187.jpg
# Resolving www.incimages.com (www.incimages.com)... 151.101.2.59, 151.101.66.59, 151.101.130.59, ...
# Connecting to www.incimages.com (www.incimages.com)|151.101.2.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124773 (122K) [image/jpeg]
# Saving to: ‘known/biden.jpg’
#
# known/biden.jpg     100%[===================>] 121.85K  --.-KB/s    in 0.01s
#
# 2021-07-06 13:24:14 (8.12 MB/s) - ‘known/biden.jpg’ saved [124773/124773]

# %%
# !wget https://media.npr.org/assets/img/2016/06/06/gettyimages-83361265_wide-5bc463f249bd1659318a5c67b48bbecbed88a220-s1600-c85.webp -O known/obama2.jpg
# Out:
# --2021-07-06 13:24:32--  https://media.npr.org/assets/img/2016/06/06/gettyimages-83361265_wide-5bc463f249bd1659318a5c67b48bbecbed88a220-s1600-c85.webp
# Resolving media.npr.org (media.npr.org)... 23.63.24.154, 2600:1406:1400:398::1155, 2600:1406:1400:391::1155
# Connecting to media.npr.org (media.npr.org)|23.63.24.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/webp]
# Saving to: ‘known/obama2.jpg’
#
# known/obama2.jpg        [ <=>                ]  93.28K  --.-KB/s    in 0.08s
#
# 2021-07-06 13:24:33 (1.16 MB/s) - ‘known/obama2.jpg’ saved [95518]

# %%
from PIL import Image, ImageDraw
from IPython.display import display

# Program koji će detektovati lica je u sledećem primeru
pil_im = Image.open('known/obama2.jpg')
display(pil_im)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1600x899 at 0x7F9EDC751A10>

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display

# Ovo je primer prepoznavanja lica na jednoj slici 
# i iscrtavanje crvenog pravougaonika oko svake identifikovane osobe (lica)

# Učitavanje slike i učenje kako da prepozna osobu 
obama_image = face_recognition.load_image_file('known/obama.jpg')
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Ucitavanje slike druge osobe i učenje kako da je prepozna
biden_image = face_recognition.load_image_file('known/bill.jpg')
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# Pravljenje niza poznatih lica i njihovih imena
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding
]
known_face_names = [
    "Barack Obama",
    "Joe Biden"
]
print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 2 images.

# %%
# Učitavanje slike sa nepoznatim licem
unknown_image = face_recognition.load_image_file('known/obama2.jpg')

# Prolanaženje svih lica na nepoznatoj slici
face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

# Slika se konvertuje u PIL-format da bi se uspešno iscrtavao pravougaonik na njoj uz pomoć Pillow biblioteke
pil_image = Image.fromarray(unknown_image)

# Pravljenje instance za uspešno crtanje
draw = ImageDraw.Draw(pil_image)

# Izlistavanje svakog lica na nepoznatoj slici
for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # Proveravanje da li se lice podudara sa poznatim licem
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    # Ili umseto toga se koristi poznato lice sa najmanjom distancom od novog lica
    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Iscrtavanje pravougaonika oko detektovanog lica
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))

    # Ispisiivanje imena ispod detektovanog lica
    text_width, text_height = draw.textsize(name)
    draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
    draw.text((left + 6, bottom - text_height - 5), name, fill=(255, 255, 255, 255))


# Uklanjanje biblioteke crteža iz memorije
del draw

# Prikazivanje rezultujuće slike
display(pil_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x899 at 0x7F9F5704AA10>

# %% [markdown]
# # **Pristup kameri za slikanje i detekciju lica**

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  # get face bounding box coordinates using Haar Cascade
  faces = face_cascade.detectMultiScale(gray)
  # draw face bounding box on image
  for (x,y,w,h) in faces:
      img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  # save image
  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %% [markdown]
# # **Primer sa traženim datasetom**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/glumci/glumci.zip
# Out:
# Archive:  gdrive/My Drive/glumci/glumci.zip
#    creating: glumci/chris_evans/
#   inflating: glumci/chris_evans/chris_evans1.png
#   inflating: glumci/chris_evans/chris_evans10.png
#   inflating: glumci/chris_evans/chris_evans11.png
#   inflating: glumci/chris_evans/chris_evans12.png
#   inflating: glumci/chris_evans/chris_evans13.png
#   inflating: glumci/chris_evans/chris_evans14.png
#   inflating: glumci/chris_evans/chris_evans15.png
#   inflating: glumci/chris_evans/chris_evans16.png
#   inflating: glumci/chris_evans/chris_evans17.png
#   inflating: glumci/chris_evans/chris_evans18.png
#   inflating: glumci/chris_evans/chris_evans19.png
#   inflating: glumci/chris_evans/chris_evans2.png
#   inflating: glumci/chris_evans/chris_evans20.png
#   inflating: glumci/chris_evans/chris_evans21.png
#   inflating: glumci/chris_evans/chris_evans22.png
#   inflating: glumci/chris_evans/chris_evans23.png
#   inflating: glumci/chris_evans/chris_evans24.png
#   inflating: glumci/chris_evans/chris_evans25.png
#   inflating: glumci/chris_evans/chris_evans26.png
#   inflating: glumci/chris_evans/chris_evans27.png
#   inflating: glumci/chris_evans/chris_evans28.png
#   inflating: glumci/chris_evans/chris_evans29.png
#   inflating: glumci/chris_evans/chris_evans3.png
#   inflating: glumci/chris_evans/chris_evans30.png
#   inflating: glumci/chris_evans/chris_evans31.png
#   inflating: glumci/chris_evans/chris_evans32.png
#   inflating: glumci/chris_evans/chris_evans33.png
#   inflating: glumci/chris_evans/chris_evans34.png
#   inflating: glumci/chris_evans/chris_evans35.png
#   inflating: glumci/chris_evans/chris_evans36.png
#   inflating: glumci/chris_evans/chris_evans37.png
#   inflating: glumci/chris_evans/chris_evans38.png
#   inflating: glumci/chris_evans/chris_evans39.png
#   inflating: glumci/chris_evans/chris_evans4.png
#   inflating: glumci/chris_evans/chris_evans40.png
#   inflating: glumci/chris_evans/chris_evans41.png
#  extracting: glumci/chris_evans/chris_evans42.png
#   inflating: glumci/chris_evans/chris_evans43.png
#   inflating: glumci/chris_evans/chris_evans44.png
#   inflating: glumci/chris_evans/chris_evans45.png
#   inflating: glumci/chris_evans/chris_evans46.png
#   inflating: glumci/chris_evans/chris_evans47.png
#   inflating: glumci/chris_evans/chris_evans48.png
#   inflating: glumci/chris_evans/chris_evans49.png
#   inflating: glumci/chris_evans/chris_evans5.png
#   inflating: glumci/chris_evans/chris_evans50.png
#   inflating: glumci/chris_evans/chris_evans6.png
#   inflating: glumci/chris_evans/chris_evans7.png
#   inflating: glumci/chris_evans/chris_evans8.png
#   inflating: glumci/chris_evans/chris_evans9.png
#    creating: glumci/chris_hemsworth/
#   inflating: glumci/chris_hemsworth/chris_hemsworth1.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth10.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth11.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth12.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth13.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth14.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth15.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth16.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth17.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth18.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth19.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth2.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth20.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth21.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth22.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth23.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth24.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth25.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth26.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth27.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth28.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth29.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth3.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth30.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth31.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth32.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth33.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth34.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth35.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth36.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth37.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth38.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth39.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth4.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth40.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth41.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth42.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth43.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth44.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth45.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth46.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth47.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth48.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth49.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth5.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth50.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth51.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth52.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth53.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth6.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth7.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth8.png
#   inflating: glumci/chris_hemsworth/chris_hemsworth9.png
#    creating: glumci/mark_ruffalo/
#   inflating: glumci/mark_ruffalo/mark_ruffalo1.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo10.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo11.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo12.png
#  extracting: glumci/mark_ruffalo/mark_ruffalo13.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo14.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo15.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo16.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo17.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo18.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo19.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo2.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo20.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo21.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo22.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo23.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo24.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo25.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo26.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo27.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo28.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo29.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo3.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo30.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo31.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo32.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo33.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo34.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo35.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo36.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo37.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo38.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo39.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo4.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo40.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo41.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo42.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo43.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo44.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo45.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo46.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo47.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo48.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo49.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo5.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo50.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo51.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo52.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo53.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo54.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo55.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo56.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo57.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo58.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo59.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo6.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo60.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo61.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo62.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo63.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo64.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo65.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo66.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo7.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo8.png
#   inflating: glumci/mark_ruffalo/mark_ruffalo9.png
#    creating: glumci/robert_downey_jr/
#   inflating: glumci/robert_downey_jr/robert_downey_jr1.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr10.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr11.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr12.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr13.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr14.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr15.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr16.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr17.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr18.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr19.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr2.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr20.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr21.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr22.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr23.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr24.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr25.png
#  extracting: glumci/robert_downey_jr/robert_downey_jr26.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr27.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr28.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr29.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr3.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr30.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr31.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr32.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr33.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr34.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr35.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr36.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr37.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr38.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr39.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr4.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr40.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr41.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr42.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr43.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr44.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr45.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr46.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr47.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr48.png
#  extracting: glumci/robert_downey_jr/robert_downey_jr49.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr5.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr50.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr51.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr6.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr7.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr8.png
#   inflating: glumci/robert_downey_jr/robert_downey_jr9.png
#    creating: glumci/scarlett_johansson/
#   inflating: glumci/scarlett_johansson/scarlett_johansson1.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson10.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson11.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson12.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson13.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson14.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson15.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson16.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson17.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson18.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson19.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson2.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson20.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson21.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson22.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson23.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson24.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson25.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson26.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson27.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson28.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson29.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson3.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson30.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson31.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson32.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson33.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson34.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson35.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson36.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson37.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson38.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson39.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson4.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson40.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson41.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson42.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson43.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson44.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson45.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson46.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson47.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson48.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson49.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson5.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson50.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson51.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson52.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson53.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson54.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson6.png
#  extracting: glumci/scarlett_johansson/scarlett_johansson7.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson8.png
#   inflating: glumci/scarlett_johansson/scarlett_johansson9.png

# %%
from PIL import Image, ImageDraw
from IPython.display import display

# Program koji će detektovati lica je u sledećem primeru
pil_im = Image.open('glumci/chris_evans/chris_evans1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=139x139 at 0x7F9E3F8C3510>

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display

# Ovo je primer prepoznavanja lica na jednoj slici 
# i iscrtavanje crvenog pravougaonika oko svake identifikovane osobe (lica)

# Učitavanje slike i učenje kako da prepozna osobu 
scarlett_image = face_recognition.load_image_file('glumci/scarlett_johansson/scarlett_johansson3.png')
mark_face_encoding = face_recognition.face_encodings(scarlett_image)[0]

# Ucitavanje slike druge osobe i učenje kako da je prepozna
chris_image = face_recognition.load_image_file('glumci/chris_evans/chris_evans1.png')
chris_face_encoding = face_recognition.face_encodings(chris_image)[0]

# Pravljenje niza poznatih lica i njihovih imena
known_face_encodings = [
    mark_face_encoding,
    chris_face_encoding
]
known_face_names = [
    "Scarlett",
    "Chris Evans"
]
print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 2 images.

# %%
# !wget https://collider.com/wp-content/uploads/the-avengers-cast-slice.jpg -O known/avengers.jpg
# Out:
# --2021-07-06 15:09:47--  https://collider.com/wp-content/uploads/the-avengers-cast-slice.jpg
# Resolving collider.com (collider.com)... 3.223.39.19
# Connecting to collider.com (collider.com)|3.223.39.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23182 (23K) [image/jpeg]
# Saving to: ‘known/avengers.jpg’
#
# known/avengers.jpg  100%[===================>]  22.64K  --.-KB/s    in 0s
#
# 2021-07-06 15:09:48 (277 MB/s) - ‘known/avengers.jpg’ saved [23182/23182]

# %%
# Učitavanje slike sa nepoznatim licem
unknown_image = face_recognition.load_image_file('known/avengers.jpg')

# Prolanaženje svih lica na nepoznatoj slici
face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

# Slika se konvertuje u PIL-format da bi se uspešno iscrtavao pravougaonik na njoj uz pomoć Pillow biblioteke
pil_image = Image.fromarray(unknown_image)

# Pravljenje instance za uspešno crtanje
draw = ImageDraw.Draw(pil_image)

# Izlistavanje svakog lica na nepoznatoj slici
for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # Proveravanje da li se lice podudara sa poznatim licem
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    # Ili umseto toga se koristi poznato lice sa najmanjom distancom od novog lica
    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Iscrtavanje pravougaonika oko detektovanog lica
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))

    # Ispisiivanje imena ispod detektovanog lica
    text_width, text_height = draw.textsize(name)
    draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
    draw.text((left + 6, bottom - text_height - 5), name, fill=(255, 255, 255, 255))


# Uklanjanje biblioteke crteža iz memorije
del draw

# Prikazivanje rezultujuće slike
display(pil_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x200 at 0x7F9E3E1C8110>

# %% [markdown]
# # **Zaključak**
#
# Rad na ovom projektu doneo mi je još jedno dodatno iskustvo u oblasti Deep Learning-a.Pošto se prvi put susrećem sa temom dosta sam istraživala i tražila odgovore, smatram da sam uspešno uradila zadatak koji mi je bio dodeljen. Tema je interesantna i može da se primeni u svakidašnjici.
# Daljim radom moguće je usavršavanje mreže, dodatni trening kao i učenje da bi se povećala sigurnost detekcije lica mreže.

# %% [markdown]
# # **Literatura**
#
#
# [1] Facial recognition system, https://en.wikipedia.org/wiki/Facial_recognition_system
#
# [2] Face recognition,  https://publicpolicy.rs/files/Jasmina%20Bajramovi%C4%87%20-%20finalno%281%29.pdf
#
# [3] FRANÇOIS CHOLLET, "Deep Learning
# with Python", 2018
#
# [4] Stan Z. Li, Anil K. Jain, "Handbook of Face Recognition", 2011
#
# [5] Omkar M. Parkhi, Andrea Vedaldi, Andrew Zisserman, University of Oxford, "Deep Face Recognition", 2015
#
# [6] Python Imaging Library,  https://en.wikipedia.org/wiki/Python_Imaging_Library
#
# [7]  Face recognition with webcam, https://www.youtube.com/watch?v=YjWh7QvVH60
